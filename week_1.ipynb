# %%
import pandas as pd
import matplotlib

# %% [markdown]
# # Import our data!

# %% [markdown]
# link to our data
# [kaggle](https://www.kaggle.com/datasets/kemical/kickstarter-projects?select=ks-projects-201801.csv)
